# %% [markdown]
# <a href="https://colab.research.google.com/github/nyac-1/trading-financial-announcements/blob/main/model_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U "tensorflow-text==2.8.*"
# !pip install -q -U tf-models-official==2.7.0
# !pip install -U tfds-nightly

# %%
import os
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds
import tensorflow_text as text  # A dependency of the preprocessing model
import tensorflow_addons as tfa
from official.nlp import optimization
import numpy as np

tf.get_logger().setLevel('ERROR')

os.environ["TFHUB_MODEL_LOAD_FORMAT"]="UNCOMPRESSED"

if tf.config.list_physical_devices('GPU'):
  strategy = tf.distribute.MirroredStrategy()
  print('Using GPU')
else:
  raise ValueError('Running on CPU is not recommended.')
# Out:
# Using GPU

# %%
# %matplotlib inline

from google.colab import drive; drive.mount('/content/gdrive', force_remount=True)
# %cd '/content/gdrive/My Drive/Colab Notebooks'

import pandas as pd
import glob
import numpy as np
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks

# %%
dir = "/content/gdrive/My Drive/nlp"
df = pd.read_csv(dir + "/latest-3.csv")

df.head()
# Out:
#                    name  sent  \
# 0  19-May-2021 50 2.pdf     0
# 1  19-May-2021 37 2.pdf     0
# 2  17-May-2021 61 2.pdf     0
# 3  19-Jun-2020 10 2.pdf     0
# 4  16-Jun-2020 96 2.pdf     0
#
#                                                 text        dates     return  \
# 0  export xmlall applicable parts notification fo...  19-May-2021  11.661808
# 1  export xmlall applicable parts notification fo...  19-May-2021  11.661808
# 2  export xmlall applicable parts notification fo...  17-May-2021   9.912536
# 3  export xml please read explanatory notes caref...  19-Jun-2020  19.218241
# 4  export xml please read explanatory notes caref...  16-Jun-2020  11.146497
#
#          sd
# 0  0.096951
# 1  0.096951
# 2  0.095899
# 3  0.233739
# 4  0.208791

# %%
texts = np.array(df['text']).astype('str')
returns = np.array(df.loc[:,['return','sd']]).astype('float32')
sentiment = np.array(df['sent']).astype('float32')

for i, string in enumerate(texts):
    string = string.split(" ")
    texts[i] = " ".join(string[int(len(string)*0.07):int(len(string)*0.95)])

# %%
tfhub_handle_encoder = "https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/3"
tfhub_handle_preprocess = "https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3"

print(f'BERT model selected           : {tfhub_handle_encoder}')
print(f'Preprocess model auto-selected: {tfhub_handle_preprocess}')
# Out:
# BERT model selected           : https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/3
# Preprocess model auto-selected: https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3

# %%
def make_bert_preprocess_model(sentence_features, seq_length = 128):
    
  input_segments = [
      tf.keras.layers.Input(shape=(), dtype=tf.string, name=ft)
      for ft in sentence_features]

  bert_preprocess = hub.load(tfhub_handle_preprocess)
  tokenizer = hub.KerasLayer(bert_preprocess.tokenize, name='tokenizer')
  segments = [tokenizer(s) for s in input_segments]

  seq_length = 512
  truncated_segments = segments

  packer = hub.KerasLayer(bert_preprocess.bert_pack_inputs, arguments=dict(seq_length=seq_length), name='packer')
  model_inputs = packer(truncated_segments)

  return tf.keras.Model(input_segments, model_inputs)

preprocessor = make_bert_preprocess_model(['input'])

# %%
def build_model():
    text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
    encoder_inputs = preprocessor(text_input)
    encoder = hub.KerasLayer(tfhub_handle_encoder, trainable=False, name='BERT_encoder')
    outputs = encoder(encoder_inputs)
    net = outputs['pooled_output']

    net = tf.keras.layers.Dropout(0.1)(net)
    net = tf.keras.layers.Dense(128, activation="relu", name='classifierOne', trainable = True)(net)
    net = tf.keras.layers.Dense(32, activation="relu", name='mid', trainable = True)(net)
    net = tf.keras.layers.Dense(16, activation="relu", name='classifierTwo', trainable = True)(net)
    net = tf.keras.layers.Dense(4, activation = "relu")(net)
    model1 = tf.keras.Model(text_input, net)

    inputB = tf.keras.layers.Input(shape=(1,), dtype = tf.int32, name = "sent")
    sent_lay_1 = tf.keras.layers.Dense(32, activation="relu", name='one', trainable = True)(inputB)
    sent_lay_2 = tf.keras.layers.Dense(8, activation="relu", name='two', trainable = True)(sent_lay_1)
    sent_lay_3 = tf.keras.layers.Dense(4, activation="relu", name='three', trainable = True)(sent_lay_2)
    model2 = tf.keras.Model(inputB, sent_lay_3)

    combined = tf.keras.layers.concatenate([model1.output, model2.output])
    final_layer_1 = tf.keras.layers.Dense(8, activation = "relu", name = "merge")(combined)
    final_layer_2 = tf.keras.layers.Dense(2, activation = "linear", name = "op")(final_layer_1)

    final_model = tf.keras.Model(inputs=[model1.input, model2.input], outputs=final_layer_2)

    return final_model

# %%
classifier_model = build_model()

# %%
classifier_model.compile(loss='mean_absolute_error', optimizer=tf.keras.optimizers.Adam())
history = classifier_model.fit([texts, sentiment], returns,epochs = 200, verbose = 1)
# Out:
# Epoch 1/200
# 17/17 [==============================] - 35s 1s/step - loss: 10.3756
# Epoch 2/200
# 17/17 [==============================] - 23s 1s/step - loss: 10.3658
# Epoch 3/200
# 17/17 [==============================] - 23s 1s/step - loss: 10.3541
# Epoch 4/200
# 17/17 [==============================] - 23s 1s/step - loss: 10.3462
# Epoch 5/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.3383
# Epoch 6/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.3223
# Epoch 7/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.3018
# Epoch 8/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2832
# Epoch 9/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2777
# Epoch 10/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2742
# Epoch 11/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2754
# Epoch 12/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2711
# Epoch 13/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2649
# Epoch 14/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2681
# Epoch 15/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2904
# Epoch 16/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2809
# Epoch 17/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2712
# Epoch 18/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2570
# Epoch 19/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2803
# Epoch 20/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2607
# Epoch 21/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2602
# Epoch 22/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2660
# Epoch 23/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2608
# Epoch 24/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2581
# Epoch 25/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2636
# Epoch 26/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2609
# Epoch 27/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2667
# Epoch 28/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2579
# Epoch 29/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2501
# Epoch 30/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2477
# Epoch 31/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2472
# Epoch 32/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2434
# Epoch 33/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2459
# Epoch 34/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2485
# Epoch 35/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2420
# Epoch 36/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2361
# Epoch 37/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2346
# Epoch 38/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2607
# Epoch 39/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2489
# Epoch 40/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2301
# Epoch 41/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2372
# Epoch 42/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2255
# Epoch 43/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2214
# Epoch 44/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2309
# Epoch 45/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2280
# Epoch 46/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2557
# Epoch 47/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2237
# Epoch 48/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2046
# Epoch 49/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2073
# Epoch 50/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2127
# Epoch 51/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2202
# Epoch 52/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.1835
# Epoch 53/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2495
# Epoch 54/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2307
# Epoch 55/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2349
# Epoch 56/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2144
# Epoch 57/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.1926
# Epoch 58/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.1810
# Epoch 59/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.1538
# Epoch 60/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.1135
# Epoch 61/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0628
# Epoch 62/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.3871
# Epoch 63/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2182
# Epoch 64/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.2178
# Epoch 65/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.1835
# Epoch 66/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.1109
# Epoch 67/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0619
# Epoch 68/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0590
# Epoch 69/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0995
# Epoch 70/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0331
# Epoch 71/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0070
# Epoch 72/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0051
# Epoch 73/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0446
# Epoch 74/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0091
# Epoch 75/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0217
# Epoch 76/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9971
# Epoch 77/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9888
# Epoch 78/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0046
# Epoch 79/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9903
# Epoch 80/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0066
# Epoch 81/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9867
# Epoch 82/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9923
# Epoch 83/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9885
# Epoch 84/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0125
# Epoch 85/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0538
# Epoch 86/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0264
# Epoch 87/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0047
# Epoch 88/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0393
# Epoch 89/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9789
# Epoch 90/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9819
# Epoch 91/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9815
# Epoch 92/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9682
# Epoch 93/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0083
# Epoch 94/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0006
# Epoch 95/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9948
# Epoch 96/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9739
# Epoch 97/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.1109
# Epoch 98/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0446
# Epoch 99/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9780
# Epoch 100/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9749
# Epoch 101/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0191
# Epoch 102/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9628
# Epoch 103/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9801
# Epoch 104/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9558
# Epoch 105/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9504
# Epoch 106/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9165
# Epoch 107/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9556
# Epoch 108/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9826
# Epoch 109/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9825
# Epoch 110/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0160
# Epoch 111/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9531
# Epoch 112/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0064
# Epoch 113/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9890
# Epoch 114/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9527
# Epoch 115/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9663
# Epoch 116/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.1451
# Epoch 117/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9541
# Epoch 118/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9311
# Epoch 119/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9447
# Epoch 120/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9201
# Epoch 121/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9312
# Epoch 122/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9186
# Epoch 123/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9282
# Epoch 124/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9038
# Epoch 125/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9270
# Epoch 126/200
# 17/17 [==============================] - 25s 1s/step - loss: 9.9197
# Epoch 127/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9040
# Epoch 128/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8915
# Epoch 129/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9432
# Epoch 130/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8669
# Epoch 131/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9774
# Epoch 132/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9035
# Epoch 133/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8686
# Epoch 134/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8891
# Epoch 135/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9199
# Epoch 136/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9747
# Epoch 137/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9027
# Epoch 138/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8622
# Epoch 139/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8489
# Epoch 140/200
# 17/17 [==============================] - 24s 1s/step - loss: 10.0255
# Epoch 141/200
# 17/17 [==============================] - 25s 1s/step - loss: 10.0528
# Epoch 142/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8962
# Epoch 143/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8665
# Epoch 144/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9267
# Epoch 145/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8712
# Epoch 146/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8580
# Epoch 147/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8795
# Epoch 148/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8785
# Epoch 149/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8273
# Epoch 150/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8217
# Epoch 151/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8903
# Epoch 152/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8914
# Epoch 153/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8535
# Epoch 154/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8768
# Epoch 155/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8672
# Epoch 156/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8107
# Epoch 157/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8251
# Epoch 158/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7649
# Epoch 159/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7970
# Epoch 160/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8557
# Epoch 161/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8558
# Epoch 162/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9289
# Epoch 163/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8248
# Epoch 164/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8051
# Epoch 165/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8066
# Epoch 166/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8380
# Epoch 167/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8227
# Epoch 168/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8026
# Epoch 169/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8340
# Epoch 170/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9072
# Epoch 171/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8889
# Epoch 172/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8135
# Epoch 173/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8188
# Epoch 174/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7393
# Epoch 175/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7845
# Epoch 176/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7769
# Epoch 177/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7442
# Epoch 178/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.9659
# Epoch 179/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8112
# Epoch 180/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8267
# Epoch 181/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7598
# Epoch 182/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7453
# Epoch 183/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7707
# Epoch 184/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7344
# Epoch 185/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8203
# Epoch 186/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7594
# Epoch 187/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7315
# Epoch 188/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8064
# Epoch 189/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.6707
# Epoch 190/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.6241
# Epoch 191/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8267
# Epoch 192/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7748
# Epoch 193/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7111
# Epoch 194/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.6587
# Epoch 195/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.8489
# Epoch 196/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7364
# Epoch 197/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7489
# Epoch 198/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.6984
# Epoch 199/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7959
# Epoch 200/200
# 17/17 [==============================] - 24s 1s/step - loss: 9.7422

# %%
predictions = classifier_model.predict([texts, sentiment])

# %%
predictions
# Out:
# array([[-0.30245554,  0.2000103 ],
#        [ 3.0178504 ,  0.15717717],
#        [ 6.761103  ,  0.08700785],
#        ...,
#        [ 2.782552  ,  0.0918714 ],
#        [ 0.9398836 ,  0.17615774],
#        [ 2.6525452 ,  0.15254143]], dtype=float32)

# %%
new_columns = ['date','return','sd']
new_df = pd.DataFrame(columns = new_columns)

# %%
new_df['date'] = df['dates']

# %%
new_df.head()
# Out:
#           date return   sd
# 0  19-May-2021    NaN  NaN
# 1  19-May-2021    NaN  NaN
# 2  17-May-2021    NaN  NaN
# 3  19-Jun-2020    NaN  NaN
# 4  16-Jun-2020    NaN  NaN

# %%
new_df[['return','sd']] = predictions

# %%
new_df.head()
# Out:
#           date    return        sd
# 0  19-May-2021 -0.302456  0.200010
# 1  19-May-2021  3.017850  0.157177
# 2  17-May-2021  6.761103  0.087008
# 3  19-Jun-2020  6.581489  0.084075
# 4  16-Jun-2020  6.581489  0.084075

# %%
new_df.to_csv("./final_prediction.csv", index = False)
