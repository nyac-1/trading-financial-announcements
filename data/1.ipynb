# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

from pathlib import Path
import requests

import os
import time

import random

# %%
url = "https://www.sgx.com/securities/company-announcements?value=AEM%20HOLDINGS%20LTD.&type=company&page=5"+"&pagesize=100"

driver = webdriver.Chrome()
driver.get(url)

wait  = lambda x: WebDriverWait(driver, x)

wait(10).until(EC.presence_of_element_located((By.TAG_NAME, 'table')))
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="427047055ce22b4412cbd4dcb89c9201", element="d85702fb-71ef-4f22-9bee-7adcb1f676f3")>

# %%
def get_all_rows(driver):
    try:
        rows = driver.find_elements_by_tag_name("table")[0].find_elements_by_tag_name("tbody")[0].find_elements_by_tag_name("tr")
        return(rows)
    except:
        print("Table not found")
        return None
    
def get_title_link(row):
    element =  row.find_elements_by_tag_name("td")[3]
    try:
        return element.find_elements_by_tag_name("a")[0].get_attribute("href")
    except:
        print("No tag found")
        return None
    
    
def download_pdfs(links, names):
    for i, link in enumerate(links):
        if(".pdf" in link):
            response = requests.get(link)
            print("Downloading file: ", i)

            pdf = open("./aem/"+ names[i]+".pdf", 'wb')
            pdf.write(response.content)
            pdf.close()

def explore_link(newDriver,link):
    newDriver.get(link)

    announcement = newDriver.find_element(By.XPATH, '//*[@id="ctl07_pnlTemplate"]/div[2]/div[3]/dl/dd[1]').text
    date = newDriver.find_element(By.XPATH, '//*[@id="ctl07_pnlTemplate"]/div[2]/div[3]/dl/dd[2]').text.split(" ")[0]
#     name = date+" "+announcement.replace("/"," ")+" File "

    div = newDriver.find_elements_by_class_name('announcement-attachment-list')
    
    all_links = []

    for element in div:
        elements = element.find_elements_by_tag_name("a")
        all_links.extend(elements)
    
    names = []
    for i in range(len(all_links)):
        names.append(date+" "+str(random.randint(1,100))+" "+str(i+1))
    return list(map(lambda x: x.get_attribute("href"), all_links)), names

# %%
rows = get_all_rows(driver)

newDriver = webdriver.Chrome()
for i, row in enumerate(rows):
    link = get_title_link(row)
    links, names = explore_link(newDriver, link)
    download_pdfs(links, names)
    print(i)
newDriver.quit()
# Out:
# Downloading file:  0
# 0
# Downloading file:  0
# 1
# Downloading file:  0
# Downloading file:  1
# 2
# Downloading file:  0
# 3
# Downloading file:  0
# 4
# Downloading file:  0
# 5
# 6
# Downloading file:  0
# Downloading file:  1
# 7
# Downloading file:  0
# 8
# Downloading file:  0
# 9
# Downloading file:  0
# Downloading file:  1
# 10
# Downloading file:  0
# Downloading file:  1
# 11
# Downloading file:  0
# Downloading file:  1
# 12
# Downloading file:  0
# Downloading file:  1
# 13
# Downloading file:  0
# Downloading file:  1
# 14
# 15
# Downloading file:  0
# Downloading file:  1
# 16
# Downloading file:  0
# Downloading file:  1
# 17
# Downloading file:  0
# 18
# Downloading file:  0
# Downloading file:  1
# 19
# Downloading file:  0
# Downloading file:  1
# 20
# Downloading file:  0
# Downloading file:  1
# 21
# Downloading file:  0
# Downloading file:  1
# 22
# Downloading file:  0
# Downloading file:  1
# 23
# Downloading file:  0
# 24
# 25
# Downloading file:  0
# 26
# Downloading file:  0
# Downloading file:  1
# 27
# 28
# Downloading file:  0
# Downloading file:  1
# 29
# Downloading file:  0
# Downloading file:  1
# 30
# Downloading file:  0
# Downloading file:  1
# 31
# Downloading file:  0
# Downloading file:  1
# 32
# Downloading file:  0
# Downloading file:  1
# 33
# Downloading file:  0
# 34
# Downloading file:  0
# 35
# Downloading file:  0
# Downloading file:  1
# 36
# Downloading file:  0
# Downloading file:  1
# 37
# Downloading file:  0
# 38
# Downloading file:  0
# 39
# Downloading file:  0
# Downloading file:  1
# 40
# Downloading file:  0
# 41
# Downloading file:  0
# Downloading file:  1
# 42
# Downloading file:  0
# 43
# 44
# 45
# 46
# Downloading file:  0
# Downloading file:  1
# 47
# 48
# 49
# 50
# 51
# Downloading file:  0
# Downloading file:  1
# 52
# Downloading file:  0
# 53
# Downloading file:  0
# Downloading file:  1
# 54
# 55
# 56
# 57
# Downloading file:  0
# 58
# Downloading file:  0
# Downloading file:  1
# 59
# Downloading file:  0
# Downloading file:  1
# 60
# Downloading file:  0
# Downloading file:  1
# 61
# Downloading file:  0
# Downloading file:  1
# 62
# Downloading file:  0
# Downloading file:  1
# 63
# Downloading file:  0
# 64
# Downloading file:  0
# Downloading file:  1
# 65
# Downloading file:  0
# Downloading file:  1
# 66
# Downloading file:  0
# 67
# Downloading file:  0
# Downloading file:  1
# Downloading file:  2
# 68
# Downloading file:  0
# Downloading file:  1
# Downloading file:  2
# 69
