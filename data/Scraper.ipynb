# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

from pathlib import Path
import requests

import os
import time

import random

# %%
url = "https://www.sgx.com/securities/company-announcements?value=AEM%20HOLDINGS%20LTD.&type=company&page=6"+"&pagesize=100"

driver = webdriver.Chrome()
driver.get(url)

wait  = lambda x: WebDriverWait(driver, x)

wait(10).until(EC.presence_of_element_located((By.TAG_NAME, 'table')))
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="948c62c6ca74313ee3fabf62712f5084", element="2fd11a32-4c5e-48c2-971e-90df1643c51c")>

# %%
def get_all_rows(driver):
    try:
        rows = driver.find_elements_by_tag_name("table")[0].find_elements_by_tag_name("tbody")[0].find_elements_by_tag_name("tr")
        return(rows)
    except:
        print("Table not found")
        return None
    
def get_title_link(row):
    element =  row.find_elements_by_tag_name("td")[3]
    try:
        return element.find_elements_by_tag_name("a")[0].get_attribute("href")
    except:
        print("No tag found")
        return None
    
    
def download_pdfs(links, names):
    for i, link in enumerate(links):
        if(".pdf" in link):
            response = requests.get(link)
            print("Downloading file: ", i)

            pdf = open("./aem/"+ names[i]+".pdf", 'wb')
            pdf.write(response.content)
            pdf.close()

def explore_link(newDriver,link):
    newDriver.get(link)

    announcement = newDriver.find_element(By.XPATH, '//*[@id="ctl07_pnlTemplate"]/div[2]/div[3]/dl/dd[1]').text
    date = newDriver.find_element(By.XPATH, '//*[@id="ctl07_pnlTemplate"]/div[2]/div[3]/dl/dd[2]').text.split(" ")[0]
#     name = date+" "+announcement.replace("/"," ")+" File "

    div = newDriver.find_elements_by_class_name('announcement-attachment-list')
    
    all_links = []

    for element in div:
        elements = element.find_elements_by_tag_name("a")
        all_links.extend(elements)
    
    names = []
    for i in range(len(all_links)):
        names.append(date+" "+str(random.randint(1,100))+" "+str(i+1))
    return list(map(lambda x: x.get_attribute("href"), all_links)), names

# %%
rows = get_all_rows(driver)

newDriver = webdriver.Chrome()
for i, row in enumerate(rows):
    link = get_title_link(row)
    links, names = explore_link(newDriver, link)
    download_pdfs(links, names)
    print(i)
newDriver.quit()
# Out:
# Downloading file:  0
# Downloading file:  1
# 0
# Downloading file:  0
# Downloading file:  1
# 1
# Downloading file:  0
# 2
# Downloading file:  0
# Downloading file:  1
# 3
# Downloading file:  0
# Downloading file:  1
# 4
# Downloading file:  0
# Downloading file:  1
# 5
# Downloading file:  0
# Downloading file:  1
# 6
# Downloading file:  0
# 7
# 8
# 9
# 10
# 11
# Downloading file:  0
# 12
# 13
# 14
# Downloading file:  0
# 15
# Downloading file:  0
# 16
# Downloading file:  0
# Downloading file:  1
# 17
# 18
# 19
# Downloading file:  0
# Downloading file:  1
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# 27
# Downloading file:  0
# 28
# 29
# 30
# 31
# 32
# Downloading file:  0
# 33
# Downloading file:  0
# 34
# Downloading file:  0
# Downloading file:  1
# 35
# 36
# 37
# 38
# 39
# 40
# Downloading file:  0
# Downloading file:  1
# 41
# Downloading file:  0
# Downloading file:  1
# 42
# 43
# Downloading file:  0
# 44
# Downloading file:  0
# 45
# 46
# 47
# Downloading file:  0
# Downloading file:  1
# 48
# Downloading file:  0
# Downloading file:  1
# 49
# Downloading file:  0
# 50
# Downloading file:  0
# 51
# Downloading file:  0
# 52
# Downloading file:  0
# 53
# 54
# 55
# 56
# 57
# Downloading file:  0
# Downloading file:  1
# 58
# Downloading file:  0
# 59
# 60
# 61
# Downloading file:  0
# Downloading file:  1
# 62
# Downloading file:  0
# Downloading file:  1
# 63
# Downloading file:  0
# 64
# 65
# Downloading file:  0
# 66
# Downloading file:  0
# Downloading file:  1
# 67
# Downloading file:  0
# Downloading file:  1
# 68
# Downloading file:  0
# Downloading file:  1
# 69
# Downloading file:  0
# Downloading file:  1
# 70
# Downloading file:  0
# Downloading file:  1
# 71
# Downloading file:  0
# Downloading file:  1
# 72
# Downloading file:  0
# Downloading file:  1
# 73
# 74
# Downloading file:  0
# 75
# Downloading file:  0
# Downloading file:  1
# 76
# Downloading file:  0
# Downloading file:  1
# 77
# Downloading file:  0
# Downloading file:  1
# 78
# Downloading file:  0
# Downloading file:  1
# 79
# Downloading file:  0
# Downloading file:  1
# 80
# Downloading file:  0
# Downloading file:  1
# 81
# Downloading file:  0
# Downloading file:  1
# 82
# Downloading file:  0
# Downloading file:  1
# 83
# Downloading file:  0
# Downloading file:  1
# 84
# Downloading file:  0
# Downloading file:  1
# 85
# Downloading file:  0
# Downloading file:  1
# 86
# Downloading file:  0
# Downloading file:  1
# 87
# Downloading file:  0
# Downloading file:  1
# 88
# Downloading file:  0
# Downloading file:  1
# Downloading file:  2
# 89
# Downloading file:  0
# 90
# Downloading file:  0
# 91
# Downloading file:  0
# 92
# Downloading file:  0
# Downloading file:  1
# 93
# Downloading file:  0
# Downloading file:  1
# 94
# Downloading file:  0
# Downloading file:  1
# 95
# 96
# Downloading file:  0
# 97
# Downloading file:  0
# Downloading file:  1
# 98
# Downloading file:  0
# Downloading file:  1
# 99
